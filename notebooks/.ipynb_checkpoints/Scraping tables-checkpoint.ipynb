# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
r = requests.get("http://embed.scribblelive.com/Embed/v7.aspx?Id=2592084&ThemeId=36126")
soup = BeautifulSoup(r.text, 'lxml')

# %%
data = soup.text

# %%
data
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nwindow.twttr = (function(d, s, id) {\r\n        var js, fjs = d.getElementsByTagName(s)[0],\r\n          t = window.twttr || {};\r\n        if (d.getElementById(id)) return t;\r\n        js = d.createElement(s);\r\n        js.id = id;\r\n        js.src = "https://platform.twitter.com/widgets.js";\r\n        fjs.parentNode.insertBefore(js, fjs);\r\n \r\n        t._e = [];\r\n        t.ready = function(f) {\r\n            t._e.push(f);\r\n        };\r\n\r\n        return t;\r\n    }(document, "script", "twitter-wjs"));\n\n(function(d, s, id) {\r\n        var js, fjs = d.getElementsByTagName(s)[0];\r\n        if (d.getElementById(id)) return;\r\n        js = d.createElement(s);\r\n        js.id = id;\r\n        js.src = "//embed.scribblelive.com/widgets/embed/post.js";\r\n            fjs.parentNode.insertBefore(js, fjs);\r\n    }(document, "script", "scrbbl-post-embed"));\n\n\n\n\n\r\n\tTransfers nach Club\r\n\n\n\n(function(d, s, id) {\r\n    wind
# ...

# %%
json = re.match('json:', data)

# %%
json

# %%
for div in soup.find_all('div',{'class':'scrbbl-post-html-wrap'}):
    print(div)

# %%
verein = []
data = []
zugänge = []
abgänge = []

# %%
for h2 in soup.find_all('h2'):
    verein.append(h2.text)

# %%
verein

# %%
for p in soup.find_all('p'):
    data.append(p.text)

# %%
for x in data: 
    if re.search(r'Zugänge:', x):
        zugänge.append(x)

# %%
for y in data:
    if re.search(r'Abgänge:', y):
        abgänge.append(y)

# %%
columns = {'verein': verein, 'zugänge': zugänge, 'abgänge': abgänge}

# %%
df = pd.DataFrame(columns)

# %%
df['abgänge'] = df['abgänge'].str.split('Abgänge: ').str.get(1)

# %%
df = df['verein', 'abgänge', 'zugänge']
